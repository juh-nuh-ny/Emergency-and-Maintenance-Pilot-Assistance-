# %%
import os
import pickle
import pdfplumber
from langchain.text_splitter import CharacterTextSplitter
from sentence_transformers import SentenceTransformer
import torch
import numpy as np
import faiss

# %%
# 1. Text extraction from each pdf
def extract_text_from_pdf(pdf_path):
    text = ""
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            page_text = page.extract_text()
            if page_text:
                text += page_text + "\n"
    return text

# 2. Load and extract all pdfs from a directory
def load_all_pdfs(pdf_directory):
    documents=[]
    
    for filename in os.listdir(pdf_directory):
        if filename.lower().endswith(".pdf"):
            full_path = os.path.join(pdf_directory, filename)
            print(f"Processing {full_path}...")
            text = extract_text_from_pdf(full_path)
            documents.append(text)
            
    return documents

# 3. Chunk into retrievable sections
def chunk_documents(documents, chunk_size=500, chunk_overlap=50):
    #tunable but works fine eitherways
    text_splitter = CharacterTextSplitter(separator = ". " ,chunk_size=chunk_size, chunk_overlap=chunk_overlap)
    chunks=[]
    for doc in documents:
        doc_chunks = text_splitter.split_text(doc)
        chunks.extend(doc_chunks)
    return chunks

# 4. Chunk Caching
def load_or_generate_chunks(pdf_directory, chunks_cache_file="chunks_cache.pkl", chunk_size=350, chunk_overlap=100):
    if os.path.exists(chunks_cache_file):
        print(f"Loading cached chunks from {chunks_cache_file}...")
        with open(chunks_cache_file, "rb") as f:
            chunks = pickle.load(f)
    else:
        print("No cached chunks found. Processing PDFs to generate chunks...")
        documents = load_all_pdfs(pdf_directory)
        chunks = chunk_documents(documents, chunk_size=chunk_size, chunk_overlap=chunk_overlap)
        print(f"Caching {len(chunks)} chunks to {chunks_cache_file}...")
        with open(chunks_cache_file, "wb") as f:
            pickle.dump(chunks, f)
    return chunks

# 5. Embeddings generation
def generate_embeddings(text_list, model_name="sentence-transformers/all-MiniLM-L6-v2", batch_size=32):
    device = "mps" if torch.backends.mps.is_available() else "cpu"
    print(f"Using device: {device}")
    model = SentenceTransformer(model_name, device=device)
    
    embeddings = model.encode(text_list, batch_size=batch_size, convert_to_tensor=True)
    return embeddings

# 6. Loading cache embeddings for saving time
def load_or_generate_embeddings(chunks, cache_file="embeddings_cache.pkl", model_name="sentence-transformers/all-MiniLM-L6-v2", batch_size=32):
    if os.path.exists(cache_file):
        with open(cache_file, "rb") as f:
            embeddings = pickle.load(f)
            
        if embeddings.shape[0] != len(chunks):
            print("Mismatch between cached embeddings and current chunk count. Regenerating embeddings.")
            embeddings = generate_embeddings(chunks, model_name=model_name, batch_size = batch_size)
            with open (cache_file, "wb") as f:
                pickle.dump(embeddings, f)
    else:
        print("No cached embeddings found, generating new ones...")
        embeddings = generate_embeddings(chunks, model_name = model_name, batch_size = batch_size)
        print(f"Caching embeddings to {cache_file}")
        with open(cache_file, "wb") as f:
            pickle.dump(embeddings, f)
    
    return embeddings
        
# 7. FAISS index build for similarity search
def build_faiss_index(embeddings):
    if torch.is_tensor(embeddings):
        embeddings_np = embeddings.cpu().numpy()
    else:
        embeddings_np = np.array(embeddings)
        
    dim = embeddings_np.shape[1]
    index = faiss.IndexFlatL2(dim)
    index.add(embeddings_np)
    return index

# %%
def main():
    pdf_directory = "/Users/jananinareshkumar/Desktop/rag/data"
    
    # Load or generate chunks from the PDFs (using cached chunks if available)
    print("Loading or generating chunks")
    chunks = load_or_generate_chunks(pdf_directory, chunks_cache_file="chunks_cache.pkl", chunk_size=350, chunk_overlap=100)
    print(f"{len(chunks)} chunks loaded.")
    
    # Generate or load cached embeddings for these chunks
    print("Embedding Generation")
    embeddings = load_or_generate_embeddings(chunks, cache_file="embeddings_cache.pkl")
    
    # Build the FAISS index
    print("FAISS Index Setup")
    index = build_faiss_index(embeddings)
    print(f"FAISS Index contains {index.ntotal} vectors.")
    
    # Query the index with a sample query
    query_text = "hydraulic failure in left engine"
    query_embedding = generate_embeddings([query_text])
    
    # Convert the query embedding to a NumPy array for FAISS
    if torch.is_tensor(query_embedding):
        query_np = query_embedding.cpu().numpy()
    else:
        query_np = np.array(query_embedding)
    
    k = 5  # Number of nearest neighbors to retrieve
    distances, indices = index.search(query_np, k)
    print("Top 5 matches", indices)
    
    # Optionally, print the text for each retrieved chunk
    for distance, idx in zip(distances[0], indices[0]):
        print(f"\nChunk index {idx} with L2 distance {distance}:")
        print(chunks[idx])
        print("=" * 80)

if __name__ == "__main__":
    main()
# Out:
# Loading or generating chunks
# No cached chunks found. Processing PDFs to generate chunks...
# Processing /Users/jananinareshkumar/Desktop/rag/data/airlines-erp-checklist.pdf...
# Processing /Users/jananinareshkumar/Desktop/rag/data/Fox-Rothschild-Emergency-Response-Handbook-Jan-2020.pdf...
# Processing /Users/jananinareshkumar/Desktop/rag/data/Accident-IncidentPreparedness.pdf...
# Processing /Users/jananinareshkumar/Desktop/rag/data/78297d73-7754-426a-9294-0b70beefae74.pdf...
# Processing /Users/jananinareshkumar/Desktop/rag/data/737-800 Quick Reference Handbook (QRH).pdf...
# Processing /Users/jananinareshkumar/Desktop/rag/data/19_afh_ch18.pdf...
# Processing /Users/jananinareshkumar/Desktop/rag/data/aviation-emergency-response-guidebook-2021.pdf...
# Processing /Users/jananinareshkumar/Desktop/rag/data/cc3.pdf...
# Processing /Users/jananinareshkumar/Desktop/rag/data/ndem_vpn_user_manual.pdf...
# Processing /Users/jananinareshkumar/Desktop/rag/data/00_afh_full.pdf...
# Processing /Users/jananinareshkumar/Desktop/rag/data/compilation-erp-4.0.pdf...
# Processing /Users/jananinareshkumar/Desktop/rag/data/AS-AMM-01-000_I1_R1_20180202.pdf...
# Processing /Users/jananinareshkumar/Desktop/rag/data/Manual of Air Traffic Services, Part-1 Edition 6.2.pdf...
# Created a chunk of size 571, which is longer than the specified 350
# Created a chunk of size 387, which is longer than the specified 350
# Created a chunk of size 360, which is longer than the specified 350
# Created a chunk of size 364, which is longer than the specified 350
# Created a chunk of size 444, which is longer than the specified 350
# Created a chunk of size 476, which is longer than the specified 350
# Created a chunk of size 3405, which is longer than the specified 350
# Created a chunk of size 1196, which is longer than the specified 350
# Created a chunk of size 702, which is longer than the specified 350
# Created a chunk of size 808, which is longer than the specified 350
# Created a chunk of size 859, which is longer than the specified 350
# Created a chunk of size 1826, which is longer than the specified 350
# Created a chunk of size 1985, which is longer than the specified 350
# Created a chunk of size 948, which is longer than the specified 350
# Created a chunk of size 3327, which is longer than the specified 350
# Created a chunk of size 508, which is longer than the specified 350
# Created a chunk of size 454, which is longer than the specified 350
# Created a chunk of size 540, which is longer than the specified 350
# Created a chunk of size 479, which is longer than the specified 350
# Created a chunk of size 763, which is longer than the specified 350
# Created a chunk of size 733, which is longer than the specified 350
# Created a chunk of size 1030, which is longer than the specified 350
# Created a chunk of size 535, which is longer than the specified 350
# Created a chunk of size 460, which is longer than the specified 350
# Created a chunk of size 679, which is longer than the specified 350
# Created a chunk of size 683, which is longer than the specified 350
# Created a chunk of size 534, which is longer than the specified 350
# Created a chunk of size 562, which is longer than the specified 350
# Created a chunk of size 570, which is longer than the specified 350
# Created a chunk of size 872, which is longer than the specified 350
# Created a chunk of size 442, which is longer than the specified 350
# Created a chunk of size 707, which is longer than the specified 350
# Created a chunk of size 1075, which is longer than the specified 350
# Created a chunk of size 501, which is longer than the specified 350
# Created a chunk of size 358, which is longer than the specified 350
# Created a chunk of size 375, which is longer than the specified 350
# Created a chunk of size 472, which is longer than the specified 350
# Created a chunk of size 1306, which is longer than the specified 350
# Created a chunk of size 1220, which is longer than the specified 350
# Created a chunk of size 599, which is longer than the specified 350
# Created a chunk of size 460, which is longer than the specified 350
# Created a chunk of size 360, which is longer than the specified 350
# Created a chunk of size 432, which is longer than the specified 350
# Created a chunk of size 523, which is longer than the specified 350
# Created a chunk of size 409, which is longer than the specified 350
# Created a chunk of size 613, which is longer than the specified 350
# Created a chunk of size 520, which is longer than the specified 350
# Created a chunk of size 1837, which is longer than the specified 350
# Created a chunk of size 1670, which is longer than the specified 350
# Created a chunk of size 737, which is longer than the specified 350
# Created a chunk of size 653, which is longer than the specified 350
# Created a chunk of size 354, which is longer than the specified 350
# Created a chunk of size 379, which is longer than the specified 350
# Created a chunk of size 936, which is longer than the specified 350
# Created a chunk of size 392, which is longer than the specified 350
# Created a chunk of size 353, which is longer than the specified 350
# Created a chunk of size 534, which is longer than the specified 350
# Created a chunk of size 1103, which is longer than the specified 350
# Created a chunk of size 7120, which is longer than the specified 350
# Created a chunk of size 1045, which is longer than the specified 350
# Created a chunk of size 431, which is longer than the specified 350
# Created a chunk of size 955, which is longer than the specified 350
# Created a chunk of size 703, which is longer than the specified 350
# Created a chunk of size 1345, which is longer than the specified 350
# Created a chunk of size 856, which is longer than the specified 350
# Created a chunk of size 510, which is longer than the specified 350
# Created a chunk of size 2884, which is longer than the specified 350
# Created a chunk of size 2330, which is longer than the specified 350
# Created a chunk of size 377, which is longer than the specified 350
# Created a chunk of size 438, which is longer than the specified 350
# Created a chunk of size 537, which is longer than the specified 350
# Created a chunk of size 419, which is longer than the specified 350
# Created a chunk of size 1247, which is longer than the specified 350
# Created a chunk of size 503, which is longer than the specified 350
# Created a chunk of size 369, which is longer than the specified 350
# Created a chunk of size 495, which is longer than the specified 350
# Created a chunk of size 767, which is longer than the specified 350
# Created a chunk of size 5334, which is longer than the specified 350
# Created a chunk of size 493, which is longer than the specified 350
# Created a chunk of size 355, which is longer than the specified 350
# Created a chunk of size 685, which is longer than the specified 350
# Created a chunk of size 585, which is longer than the specified 350
# Created a chunk of size 842, which is longer than the specified 350
# Created a chunk of size 396, which is longer than the specified 350
# Created a chunk of size 368, which is longer than the specified 350
# Created a chunk of size 473, which is longer than the specified 350
# Created a chunk of size 1159, which is longer than the specified 350
# Created a chunk of size 5931, which is longer than the specified 350
# Created a chunk of size 388, which is longer than the specified 350
# Created a chunk of size 4970, which is longer than the specified 350
# Created a chunk of size 3157, which is longer than the specified 350
# Created a chunk of size 1811, which is longer than the specified 350
# Created a chunk of size 4408, which is longer than the specified 350
# Created a chunk of size 414, which is longer than the specified 350
# Created a chunk of size 1227, which is longer than the specified 350
# Created a chunk of size 1090, which is longer than the specified 350
# Created a chunk of size 1432, which is longer than the specified 350
# Created a chunk of size 1297, which is longer than the specified 350
# Created a chunk of size 1742, which is longer than the specified 350
# Created a chunk of size 768, which is longer than the specified 350
# Created a chunk of size 628, which is longer than the specified 350
# Created a chunk of size 3899, which is longer than the specified 350
# Created a chunk of size 468, which is longer than the specified 350
# Created a chunk of size 749, which is longer than the specified 350
# Created a chunk of size 420, which is longer than the specified 350
# Created a chunk of size 570, which is longer than the specified 350
# Created a chunk of size 646, which is longer than the specified 350
# Created a chunk of size 487, which is longer than the specified 350
# Created a chunk of size 604, which is longer than the specified 350
# Created a chunk of size 436, which is longer than the specified 350
# Created a chunk of size 493, which is longer than the specified 350
# Created a chunk of size 577, which is longer than the specified 350
# Created a chunk of size 384, which is longer than the specified 350
# Created a chunk of size 1781, which is longer than the specified 350
# Created a chunk of size 2975, which is longer than the specified 350
# Created a chunk of size 5563, which is longer than the specified 350
# Created a chunk of size 2915, which is longer than the specified 350
# Created a chunk of size 361, which is longer than the specified 350
# Created a chunk of size 2544, which is longer than the specified 350
# Created a chunk of size 575, which is longer than the specified 350
# Created a chunk of size 900, which is longer than the specified 350
# Created a chunk of size 441, which is longer than the specified 350
# Created a chunk of size 586, which is longer than the specified 350
# Created a chunk of size 408, which is longer than the specified 350
# Created a chunk of size 1910, which is longer than the specified 350
# Created a chunk of size 805, which is longer than the specified 350
# Created a chunk of size 615, which is longer than the specified 350
# Created a chunk of size 506, which is longer than the specified 350
# Created a chunk of size 629, which is longer than the specified 350
# Created a chunk of size 354, which is longer than the specified 350
# Created a chunk of size 536, which is longer than the specified 350
# Created a chunk of size 444, which is longer than the specified 350
# Created a chunk of size 437, which is longer than the specified 350
# Created a chunk of size 520, which is longer than the specified 350
# Created a chunk of size 418, which is longer than the specified 350
# Created a chunk of size 591, which is longer than the specified 350
# Created a chunk of size 542, which is longer than the specified 350
# Created a chunk of size 395, which is longer than the specified 350
# Created a chunk of size 425, which is longer than the specified 350
# Created a chunk of size 502, which is longer than the specified 350
# Created a chunk of size 421, which is longer than the specified 350
# Created a chunk of size 1369, which is longer than the specified 350
# Created a chunk of size 628, which is longer than the specified 350
# Created a chunk of size 408, which is longer than the specified 350
# Created a chunk of size 375, which is longer than the specified 350
# Created a chunk of size 593, which is longer than the specified 350
# Created a chunk of size 394, which is longer than the specified 350
# Created a chunk of size 404, which is longer than the specified 350
# Created a chunk of size 458, which is longer than the specified 350
# Created a chunk of size 430, which is longer than the specified 350
# Created a chunk of size 426, which is longer than the specified 350
# Created a chunk of size 420, which is longer than the specified 350
# Created a chunk of size 903, which is longer than the specified 350
# Created a chunk of size 509, which is longer than the specified 350
# Created a chunk of size 574, which is longer than the specified 350
# Created a chunk of size 554, which is longer than the specified 350
# Created a chunk of size 459, which is longer than the specified 350
# Created a chunk of size 381, which is longer than the specified 350
# Created a chunk of size 492, which is longer than the specified 350
# Created a chunk of size 354, which is longer than the specified 350
# Created a chunk of size 398, which is longer than the specified 350
# Created a chunk of size 440, which is longer than the specified 350
# Created a chunk of size 406, which is longer than the specified 350
# Created a chunk of size 1758, which is longer than the specified 350
# Created a chunk of size 475, which is longer than the specified 350
# Created a chunk of size 1761, which is longer than the specified 350
# Created a chunk of size 3004, which is longer than the specified 350
# Created a chunk of size 2081, which is longer than the specified 350
# Created a chunk of size 545, which is longer than the specified 350
# Created a chunk of size 1603, which is longer than the specified 350
# Created a chunk of size 877, which is longer than the specified 350
# Created a chunk of size 719, which is longer than the specified 350
# Created a chunk of size 570, which is longer than the specified 350
# Created a chunk of size 791, which is longer than the specified 350
# Created a chunk of size 1148, which is longer than the specified 350
# Created a chunk of size 1019, which is longer than the specified 350
# Created a chunk of size 957, which is longer than the specified 350
# Created a chunk of size 1015, which is longer than the specified 350
# Created a chunk of size 908, which is longer than the specified 350
# Created a chunk of size 1254, which is longer than the specified 350
# Created a chunk of size 443, which is longer than the specified 350
# Created a chunk of size 382, which is longer than the specified 350
# Created a chunk of size 482, which is longer than the specified 350
# Created a chunk of size 369, which is longer than the specified 350
# Created a chunk of size 455, which is longer than the specified 350
# Created a chunk of size 689, which is longer than the specified 350
# Created a chunk of size 376, which is longer than the specified 350
# Created a chunk of size 399, which is longer than the specified 350
# Created a chunk of size 5266, which is longer than the specified 350
# Created a chunk of size 515, which is longer than the specified 350
# Created a chunk of size 521, which is longer than the specified 350
# Created a chunk of size 360, which is longer than the specified 350
# Created a chunk of size 449, which is longer than the specified 350
# Created a chunk of size 1886, which is longer than the specified 350
# Created a chunk of size 363, which is longer than the specified 350
# Created a chunk of size 415, which is longer than the specified 350
# Created a chunk of size 514, which is longer than the specified 350
# Created a chunk of size 428, which is longer than the specified 350
# Created a chunk of size 416, which is longer than the specified 350
# Created a chunk of size 584, which is longer than the specified 350
# Created a chunk of size 517, which is longer than the specified 350
# Created a chunk of size 438, which is longer than the specified 350
# Created a chunk of size 390, which is longer than the specified 350
# Created a chunk of size 922, which is longer than the specified 350
# Created a chunk of size 356, which is longer than the specified 350
# Created a chunk of size 409, which is longer than the specified 350
# Created a chunk of size 450, which is longer than the specified 350
# Created a chunk of size 679, which is longer than the specified 350
# Created a chunk of size 437, which is longer than the specified 350
# Created a chunk of size 352, which is longer than the specified 350
# Created a chunk of size 867, which is longer than the specified 350
# Created a chunk of size 377, which is longer than the specified 350
# Created a chunk of size 1545, which is longer than the specified 350
# Created a chunk of size 497, which is longer than the specified 350
# Created a chunk of size 562, which is longer than the specified 350
# Created a chunk of size 405, which is longer than the specified 350
# Created a chunk of size 533, which is longer than the specified 350
# Created a chunk of size 1009, which is longer than the specified 350
# Created a chunk of size 638, which is longer than the specified 350
# Created a chunk of size 371, which is longer than the specified 350
# Created a chunk of size 390, which is longer than the specified 350
# Created a chunk of size 781, which is longer than the specified 350
# Created a chunk of size 1457, which is longer than the specified 350
# Created a chunk of size 2136, which is longer than the specified 350
# Created a chunk of size 725, which is longer than the specified 350
# Created a chunk of size 4003, which is longer than the specified 350
# Created a chunk of size 459, which is longer than the specified 350
# Created a chunk of size 860, which is longer than the specified 350
# Created a chunk of size 445, which is longer than the specified 350
# Created a chunk of size 1307, which is longer than the specified 350
# Created a chunk of size 1005, which is longer than the specified 350
# Created a chunk of size 1484, which is longer than the specified 350
# Created a chunk of size 701, which is longer than the specified 350
# Created a chunk of size 538, which is longer than the specified 350
# Created a chunk of size 6254, which is longer than the specified 350
# Created a chunk of size 1125, which is longer than the specified 350
# Created a chunk of size 376, which is longer than the specified 350
# Created a chunk of size 689, which is longer than the specified 350
# Created a chunk of size 1488, which is longer than the specified 350
# Created a chunk of size 618, which is longer than the specified 350
# Created a chunk of size 874, which is longer than the specified 350
# Created a chunk of size 4143, which is longer than the specified 350
# Created a chunk of size 564, which is longer than the specified 350
# Created a chunk of size 376, which is longer than the specified 350
# Created a chunk of size 1777, which is longer than the specified 350
# Created a chunk of size 642, which is longer than the specified 350
# Created a chunk of size 706, which is longer than the specified 350
# Created a chunk of size 480, which is longer than the specified 350
# Created a chunk of size 548, which is longer than the specified 350
# Created a chunk of size 728, which is longer than the specified 350
# Created a chunk of size 371, which is longer than the specified 350
# Created a chunk of size 479, which is longer than the specified 350
# Created a chunk of size 614, which is longer than the specified 350
# Created a chunk of size 526, which is longer than the specified 350
# Created a chunk of size 1354, which is longer than the specified 350
# Created a chunk of size 918, which is longer than the specified 350
# Created a chunk of size 652, which is longer than the specified 350
# Created a chunk of size 602, which is longer than the specified 350
# Created a chunk of size 644, which is longer than the specified 350
# Created a chunk of size 1089, which is longer than the specified 350
# Created a chunk of size 1674, which is longer than the specified 350
# Created a chunk of size 542, which is longer than the specified 350
# Created a chunk of size 489, which is longer than the specified 350
# Created a chunk of size 464, which is longer than the specified 350
# Created a chunk of size 863, which is longer than the specified 350
# Created a chunk of size 487, which is longer than the specified 350
# Created a chunk of size 375, which is longer than the specified 350
# Created a chunk of size 1270, which is longer than the specified 350
# Created a chunk of size 429, which is longer than the specified 350
# Created a chunk of size 614, which is longer than the specified 350
# Created a chunk of size 810, which is longer than the specified 350
# Created a chunk of size 779, which is longer than the specified 350
# Created a chunk of size 440, which is longer than the specified 350
# Created a chunk of size 1784, which is longer than the specified 350
# Created a chunk of size 553, which is longer than the specified 350
# Created a chunk of size 371, which is longer than the specified 350
# Created a chunk of size 351, which is longer than the specified 350
# Created a chunk of size 423, which is longer than the specified 350
# Created a chunk of size 373, which is longer than the specified 350
# Created a chunk of size 700, which is longer than the specified 350
# Created a chunk of size 698, which is longer than the specified 350
# Created a chunk of size 604, which is longer than the specified 350
# Created a chunk of size 1751, which is longer than the specified 350
# Created a chunk of size 845, which is longer than the specified 350
# Created a chunk of size 742, which is longer than the specified 350
# Created a chunk of size 641, which is longer than the specified 350
# Created a chunk of size 360, which is longer than the specified 350
# Created a chunk of size 756, which is longer than the specified 350
# Created a chunk of size 698, which is longer than the specified 350
# Created a chunk of size 497, which is longer than the specified 350
# Created a chunk of size 1248, which is longer than the specified 350
# Created a chunk of size 579, which is longer than the specified 350
# Created a chunk of size 523, which is longer than the specified 350
# Created a chunk of size 406, which is longer than the specified 350
# Created a chunk of size 871, which is longer than the specified 350
# Created a chunk of size 351, which is longer than the specified 350
# Created a chunk of size 1074, which is longer than the specified 350
# Created a chunk of size 502, which is longer than the specified 350
# Created a chunk of size 685, which is longer than the specified 350
# Created a chunk of size 377, which is longer than the specified 350
# Created a chunk of size 845, which is longer than the specified 350
# Created a chunk of size 526, which is longer than the specified 350
# Created a chunk of size 479, which is longer than the specified 350
# Created a chunk of size 478, which is longer than the specified 350
# Created a chunk of size 893, which is longer than the specified 350
# Created a chunk of size 473, which is longer than the specified 350
# Created a chunk of size 512, which is longer than the specified 350
# Created a chunk of size 397, which is longer than the specified 350
# Created a chunk of size 1412, which is longer than the specified 350
# Created a chunk of size 455, which is longer than the specified 350
# Created a chunk of size 423, which is longer than the specified 350
# Created a chunk of size 417, which is longer than the specified 350
# Created a chunk of size 718, which is longer than the specified 350
# Created a chunk of size 588, which is longer than the specified 350
# Created a chunk of size 411, which is longer than the specified 350
# Created a chunk of size 435, which is longer than the specified 350
# Created a chunk of size 1966, which is longer than the specified 350
# Created a chunk of size 423, which is longer than the specified 350
# Created a chunk of size 501, which is longer than the specified 350
# Created a chunk of size 657, which is longer than the specified 350
# Created a chunk of size 431, which is longer than the specified 350
# Created a chunk of size 932, which is longer than the specified 350
# Created a chunk of size 678, which is longer than the specified 350
# Created a chunk of size 454, which is longer than the specified 350
# Created a chunk of size 409, which is longer than the specified 350
# Created a chunk of size 352, which is longer than the specified 350
# Created a chunk of size 684, which is longer than the specified 350
# Created a chunk of size 1058, which is longer than the specified 350
# Created a chunk of size 798, which is longer than the specified 350
# Created a chunk of size 446, which is longer than the specified 350
# Created a chunk of size 904, which is longer than the specified 350
# Created a chunk of size 386, which is longer than the specified 350
# Created a chunk of size 532, which is longer than the specified 350
# Created a chunk of size 359, which is longer than the specified 350
# Created a chunk of size 386, which is longer than the specified 350
# Created a chunk of size 378, which is longer than the specified 350
# Created a chunk of size 607, which is longer than the specified 350
# Created a chunk of size 368, which is longer than the specified 350
# Created a chunk of size 739, which is longer than the specified 350
# Created a chunk of size 729, which is longer than the specified 350
# Created a chunk of size 668, which is longer than the specified 350
# Created a chunk of size 421, which is longer than the specified 350
# Created a chunk of size 448, which is longer than the specified 350
# Created a chunk of size 389, which is longer than the specified 350
# Created a chunk of size 443, which is longer than the specified 350
# Created a chunk of size 399, which is longer than the specified 350
# Created a chunk of size 386, which is longer than the specified 350
# Created a chunk of size 412, which is longer than the specified 350
# Created a chunk of size 526, which is longer than the specified 350
# Created a chunk of size 566, which is longer than the specified 350
# Created a chunk of size 1408, which is longer than the specified 350
# Created a chunk of size 691, which is longer than the specified 350
# Created a chunk of size 375, which is longer than the specified 350
# Created a chunk of size 6696, which is longer than the specified 350
# Created a chunk of size 470, which is longer than the specified 350
# Created a chunk of size 388, which is longer than the specified 350
# Created a chunk of size 572, which is longer than the specified 350
# Created a chunk of size 662, which is longer than the specified 350
# Created a chunk of size 601, which is longer than the specified 350
# Created a chunk of size 704, which is longer than the specified 350
# Created a chunk of size 485, which is longer than the specified 350
# Created a chunk of size 1081, which is longer than the specified 350
# Created a chunk of size 466, which is longer than the specified 350
# Created a chunk of size 394, which is longer than the specified 350
# Created a chunk of size 351, which is longer than the specified 350
# Created a chunk of size 421, which is longer than the specified 350
# Created a chunk of size 409, which is longer than the specified 350
# Created a chunk of size 488, which is longer than the specified 350
# Created a chunk of size 633150, which is longer than the specified 350
# Created a chunk of size 616, which is longer than the specified 350
# Created a chunk of size 513, which is longer than the specified 350
# Created a chunk of size 517, which is longer than the specified 350
# Created a chunk of size 448, which is longer than the specified 350
# Created a chunk of size 404, which is longer than the specified 350
# Created a chunk of size 365, which is longer than the specified 350
# Created a chunk of size 365, which is longer than the specified 350
# Created a chunk of size 356, which is longer than the specified 350
# Created a chunk of size 620, which is longer than the specified 350
# Created a chunk of size 392, which is longer than the specified 350
# Created a chunk of size 727, which is longer than the specified 350
# Created a chunk of size 1252, which is longer than the specified 350
# Created a chunk of size 1154, which is longer than the specified 350
# Created a chunk of size 822, which is longer than the specified 350
# Created a chunk of size 459, which is longer than the specified 350
# Created a chunk of size 930, which is longer than the specified 350
# Created a chunk of size 444, which is longer than the specified 350
# Created a chunk of size 915, which is longer than the specified 350
# Created a chunk of size 385, which is longer than the specified 350
# Created a chunk of size 601, which is longer than the specified 350
# Created a chunk of size 415, which is longer than the specified 350
# Created a chunk of size 428, which is longer than the specified 350
# Created a chunk of size 569, which is longer than the specified 350
# Created a chunk of size 2038, which is longer than the specified 350
# Created a chunk of size 491, which is longer than the specified 350
# Created a chunk of size 524, which is longer than the specified 350
# Created a chunk of size 393, which is longer than the specified 350
# Created a chunk of size 364, which is longer than the specified 350
# Created a chunk of size 486, which is longer than the specified 350
# Created a chunk of size 886, which is longer than the specified 350
# Created a chunk of size 473, which is longer than the specified 350
# Created a chunk of size 482, which is longer than the specified 350
# Created a chunk of size 2135, which is longer than the specified 350
# Created a chunk of size 1097, which is longer than the specified 350
# Created a chunk of size 1523, which is longer than the specified 350
# Created a chunk of size 410, which is longer than the specified 350
# Created a chunk of size 580, which is longer than the specified 350
# Created a chunk of size 2019, which is longer than the specified 350
# Created a chunk of size 580, which is longer than the specified 350
# Created a chunk of size 490, which is longer than the specified 350
# Created a chunk of size 485, which is longer than the specified 350
# Created a chunk of size 409, which is longer than the specified 350
# Created a chunk of size 376, which is longer than the specified 350
# Created a chunk of size 521, which is longer than the specified 350
# Created a chunk of size 678, which is longer than the specified 350
# Created a chunk of size 791, which is longer than the specified 350
# Created a chunk of size 663, which is longer than the specified 350
# Created a chunk of size 683, which is longer than the specified 350
# Created a chunk of size 1121, which is longer than the specified 350
# Created a chunk of size 399, which is longer than the specified 350
# Created a chunk of size 532, which is longer than the specified 350
# Created a chunk of size 700, which is longer than the specified 350
# Created a chunk of size 890, which is longer than the specified 350
# Created a chunk of size 365, which is longer than the specified 350
# Created a chunk of size 472, which is longer than the specified 350
# Created a chunk of size 363, which is longer than the specified 350
# Created a chunk of size 612, which is longer than the specified 350
# Created a chunk of size 692, which is longer than the specified 350
# Created a chunk of size 1089, which is longer than the specified 350
# Created a chunk of size 365, which is longer than the specified 350
# Created a chunk of size 462, which is longer than the specified 350
# Created a chunk of size 434, which is longer than the specified 350
# Created a chunk of size 482, which is longer than the specified 350
# Created a chunk of size 907, which is longer than the specified 350
# Created a chunk of size 420, which is longer than the specified 350
# Created a chunk of size 440, which is longer than the specified 350
# Created a chunk of size 482, which is longer than the specified 350
# Created a chunk of size 541, which is longer than the specified 350
# Created a chunk of size 578, which is longer than the specified 350
# Created a chunk of size 634, which is longer than the specified 350
# Created a chunk of size 431, which is longer than the specified 350
# Created a chunk of size 799, which is longer than the specified 350
# Created a chunk of size 549, which is longer than the specified 350
# Created a chunk of size 574, which is longer than the specified 350
# Created a chunk of size 491, which is longer than the specified 350
# Created a chunk of size 411, which is longer than the specified 350
# Created a chunk of size 552, which is longer than the specified 350
# Created a chunk of size 501, which is longer than the specified 350
# Created a chunk of size 358, which is longer than the specified 350
# Created a chunk of size 364, which is longer than the specified 350
# Created a chunk of size 450, which is longer than the specified 350
# Created a chunk of size 744, which is longer than the specified 350
# Created a chunk of size 589, which is longer than the specified 350
# Created a chunk of size 469, which is longer than the specified 350
# Created a chunk of size 384, which is longer than the specified 350
# Created a chunk of size 1243, which is longer than the specified 350
# Created a chunk of size 436, which is longer than the specified 350
# Created a chunk of size 800, which is longer than the specified 350
# Created a chunk of size 755, which is longer than the specified 350
# Created a chunk of size 571, which is longer than the specified 350
# Created a chunk of size 360, which is longer than the specified 350
# Created a chunk of size 426, which is longer than the specified 350
# Created a chunk of size 493, which is longer than the specified 350
# Created a chunk of size 557, which is longer than the specified 350
# Created a chunk of size 777, which is longer than the specified 350
# Created a chunk of size 784, which is longer than the specified 350
# Created a chunk of size 735, which is longer than the specified 350
# Created a chunk of size 467, which is longer than the specified 350
# Created a chunk of size 505, which is longer than the specified 350
# Created a chunk of size 642, which is longer than the specified 350
# Created a chunk of size 503, which is longer than the specified 350
# Created a chunk of size 633, which is longer than the specified 350
# Created a chunk of size 396, which is longer than the specified 350
# Created a chunk of size 1972, which is longer than the specified 350
# Created a chunk of size 648, which is longer than the specified 350
# Created a chunk of size 1496, which is longer than the specified 350
# Created a chunk of size 675, which is longer than the specified 350
# Created a chunk of size 607, which is longer than the specified 350
# Created a chunk of size 1622, which is longer than the specified 350
# Created a chunk of size 390, which is longer than the specified 350
# Created a chunk of size 1352, which is longer than the specified 350
# Created a chunk of size 376, which is longer than the specified 350
# Created a chunk of size 476, which is longer than the specified 350
# Created a chunk of size 421, which is longer than the specified 350
# Created a chunk of size 383, which is longer than the specified 350
# Created a chunk of size 1120, which is longer than the specified 350
# Created a chunk of size 651, which is longer than the specified 350
# Created a chunk of size 386, which is longer than the specified 350
# Created a chunk of size 765, which is longer than the specified 350
# Created a chunk of size 804, which is longer than the specified 350
# Created a chunk of size 412, which is longer than the specified 350
# Created a chunk of size 519, which is longer than the specified 350
# Created a chunk of size 429, which is longer than the specified 350
# Created a chunk of size 361, which is longer than the specified 350
# Created a chunk of size 499, which is longer than the specified 350
# Created a chunk of size 1413, which is longer than the specified 350
# Created a chunk of size 471, which is longer than the specified 350
# Created a chunk of size 548, which is longer than the specified 350
# Created a chunk of size 659, which is longer than the specified 350
# Created a chunk of size 371, which is longer than the specified 350
# Created a chunk of size 415, which is longer than the specified 350
# Created a chunk of size 389, which is longer than the specified 350
# Created a chunk of size 3940, which is longer than the specified 350
# Created a chunk of size 1418, which is longer than the specified 350
# Created a chunk of size 1449, which is longer than the specified 350
# Created a chunk of size 955, which is longer than the specified 350
# Created a chunk of size 703, which is longer than the specified 350
# Created a chunk of size 1342, which is longer than the specified 350
# Created a chunk of size 1482, which is longer than the specified 350
# Created a chunk of size 5176, which is longer than the specified 350
# Created a chunk of size 480, which is longer than the specified 350
# Created a chunk of size 971, which is longer than the specified 350
# Created a chunk of size 2180, which is longer than the specified 350
# Created a chunk of size 2394, which is longer than the specified 350
# Created a chunk of size 3143, which is longer than the specified 350
# Created a chunk of size 2473, which is longer than the specified 350
# Created a chunk of size 1198, which is longer than the specified 350
# Created a chunk of size 2011, which is longer than the specified 350
# Created a chunk of size 2362, which is longer than the specified 350
# Created a chunk of size 387, which is longer than the specified 350
# Created a chunk of size 8273, which is longer than the specified 350
# Created a chunk of size 463, which is longer than the specified 350
# Created a chunk of size 3029, which is longer than the specified 350
# Created a chunk of size 588, which is longer than the specified 350
# Created a chunk of size 8681, which is longer than the specified 350
# Created a chunk of size 9101, which is longer than the specified 350
# Created a chunk of size 14929, which is longer than the specified 350
# Created a chunk of size 447, which is longer than the specified 350
# Created a chunk of size 969, which is longer than the specified 350
# Created a chunk of size 834, which is longer than the specified 350
# Created a chunk of size 1187, which is longer than the specified 350
# Created a chunk of size 7383, which is longer than the specified 350
# Created a chunk of size 2190, which is longer than the specified 350
# Created a chunk of size 4383, which is longer than the specified 350
# Created a chunk of size 1256, which is longer than the specified 350
# Created a chunk of size 4180, which is longer than the specified 350
# Created a chunk of size 1560, which is longer than the specified 350
# Created a chunk of size 1954, which is longer than the specified 350
# Created a chunk of size 2769, which is longer than the specified 350
# Created a chunk of size 2668, which is longer than the specified 350
# Created a chunk of size 1983, which is longer than the specified 350
# Created a chunk of size 2639, which is longer than the specified 350
# Created a chunk of size 2436, which is longer than the specified 350
# Created a chunk of size 1521, which is longer than the specified 350
# Created a chunk of size 2658, which is longer than the specified 350
# Created a chunk of size 18647, which is longer than the specified 350
# Created a chunk of size 2527, which is longer than the specified 350
# Created a chunk of size 830, which is longer than the specified 350
# Created a chunk of size 6054, which is longer than the specified 350
# Created a chunk of size 595, which is longer than the specified 350
# Created a chunk of size 600, which is longer than the specified 350
# Created a chunk of size 447, which is longer than the specified 350
# Created a chunk of size 1577, which is longer than the specified 350
# Created a chunk of size 551, which is longer than the specified 350
# Created a chunk of size 1257, which is longer than the specified 350
# Created a chunk of size 399, which is longer than the specified 350
# Created a chunk of size 11719, which is longer than the specified 350
# Created a chunk of size 3546, which is longer than the specified 350
# Created a chunk of size 2136, which is longer than the specified 350
# Created a chunk of size 367, which is longer than the specified 350
# Created a chunk of size 2061, which is longer than the specified 350
# Created a chunk of size 2935, which is longer than the specified 350
# Created a chunk of size 1170, which is longer than the specified 350
# Created a chunk of size 2130, which is longer than the specified 350
# Created a chunk of size 380, which is longer than the specified 350
# Created a chunk of size 373, which is longer than the specified 350
# Created a chunk of size 2216, which is longer than the specified 350
# Created a chunk of size 496, which is longer than the specified 350
# Created a chunk of size 1617, which is longer than the specified 350
# Created a chunk of size 1236, which is longer than the specified 350
# Created a chunk of size 1065, which is longer than the specified 350
# Created a chunk of size 352, which is longer than the specified 350
# Created a chunk of size 1758, which is longer than the specified 350
# Created a chunk of size 425, which is longer than the specified 350
# Created a chunk of size 461, which is longer than the specified 350
# Created a chunk of size 433, which is longer than the specified 350
# Created a chunk of size 1248, which is longer than the specified 350
# Created a chunk of size 398, which is longer than the specified 350
# Created a chunk of size 730, which is longer than the specified 350
# Created a chunk of size 892, which is longer than the specified 350
# Created a chunk of size 529, which is longer than the specified 350
# Created a chunk of size 883, which is longer than the specified 350
# Created a chunk of size 1349, which is longer than the specified 350
# Created a chunk of size 689, which is longer than the specified 350
# Created a chunk of size 450, which is longer than the specified 350
# Created a chunk of size 1698, which is longer than the specified 350
# Created a chunk of size 506, which is longer than the specified 350
# Created a chunk of size 514, which is longer than the specified 350
# Created a chunk of size 351, which is longer than the specified 350
# Created a chunk of size 839, which is longer than the specified 350
# Created a chunk of size 458, which is longer than the specified 350
# Created a chunk of size 382, which is longer than the specified 350
# Created a chunk of size 532, which is longer than the specified 350
# Created a chunk of size 373, which is longer than the specified 350
# Created a chunk of size 631, which is longer than the specified 350
# Created a chunk of size 776, which is longer than the specified 350
# Created a chunk of size 425, which is longer than the specified 350
# Created a chunk of size 616, which is longer than the specified 350
# Created a chunk of size 404, which is longer than the specified 350
# Created a chunk of size 378, which is longer than the specified 350
# Created a chunk of size 384, which is longer than the specified 350
# Created a chunk of size 473, which is longer than the specified 350
# Created a chunk of size 800, which is longer than the specified 350
# Created a chunk of size 396, which is longer than the specified 350
# Created a chunk of size 353, which is longer than the specified 350
# Created a chunk of size 353, which is longer than the specified 350
# Created a chunk of size 404, which is longer than the specified 350
# Created a chunk of size 458, which is longer than the specified 350
# Created a chunk of size 700, which is longer than the specified 350
# Created a chunk of size 860, which is longer than the specified 350
# Created a chunk of size 364, which is longer than the specified 350
# Created a chunk of size 453, which is longer than the specified 350
# Created a chunk of size 433, which is longer than the specified 350
# Created a chunk of size 465, which is longer than the specified 350
# Created a chunk of size 369, which is longer than the specified 350
# Created a chunk of size 625, which is longer than the specified 350
# Created a chunk of size 487, which is longer than the specified 350
# Created a chunk of size 531, which is longer than the specified 350
# Created a chunk of size 420, which is longer than the specified 350
# Created a chunk of size 430, which is longer than the specified 350
# Created a chunk of size 376, which is longer than the specified 350
# Created a chunk of size 378, which is longer than the specified 350
# Created a chunk of size 518, which is longer than the specified 350
# Created a chunk of size 367, which is longer than the specified 350
# Created a chunk of size 744, which is longer than the specified 350
# Created a chunk of size 701, which is longer than the specified 350
# Created a chunk of size 438, which is longer than the specified 350
# Created a chunk of size 417, which is longer than the specified 350
# Created a chunk of size 456, which is longer than the specified 350
# Created a chunk of size 385, which is longer than the specified 350
# Created a chunk of size 395, which is longer than the specified 350
# Created a chunk of size 545, which is longer than the specified 350
# Created a chunk of size 373, which is longer than the specified 350
# Created a chunk of size 540, which is longer than the specified 350
# Created a chunk of size 450, which is longer than the specified 350
# Created a chunk of size 450, which is longer than the specified 350
# Created a chunk of size 516, which is longer than the specified 350
# Created a chunk of size 458, which is longer than the specified 350
# Created a chunk of size 686, which is longer than the specified 350
# Created a chunk of size 556, which is longer than the specified 350
# Created a chunk of size 420, which is longer than the specified 350
# Created a chunk of size 366, which is longer than the specified 350
# Created a chunk of size 461, which is longer than the specified 350
# Created a chunk of size 463, which is longer than the specified 350
# Created a chunk of size 515, which is longer than the specified 350
# Created a chunk of size 374, which is longer than the specified 350
# Created a chunk of size 504, which is longer than the specified 350
# Created a chunk of size 644, which is longer than the specified 350
# Created a chunk of size 538, which is longer than the specified 350
# Created a chunk of size 564, which is longer than the specified 350
# Created a chunk of size 444, which is longer than the specified 350
# Created a chunk of size 415, which is longer than the specified 350
# Created a chunk of size 538, which is longer than the specified 350
# Created a chunk of size 590, which is longer than the specified 350
# Created a chunk of size 383, which is longer than the specified 350
# Created a chunk of size 430, which is longer than the specified 350
# Created a chunk of size 532, which is longer than the specified 350
# Created a chunk of size 882, which is longer than the specified 350
# Created a chunk of size 413, which is longer than the specified 350
# Created a chunk of size 1216, which is longer than the specified 350
# Created a chunk of size 778, which is longer than the specified 350
# Created a chunk of size 954, which is longer than the specified 350
# Created a chunk of size 403, which is longer than the specified 350
# Created a chunk of size 352, which is longer than the specified 350
# Created a chunk of size 392, which is longer than the specified 350
# Created a chunk of size 1180, which is longer than the specified 350
# Created a chunk of size 442, which is longer than the specified 350
# Created a chunk of size 441, which is longer than the specified 350
# Created a chunk of size 413, which is longer than the specified 350
# Created a chunk of size 600, which is longer than the specified 350
# Created a chunk of size 648, which is longer than the specified 350
# Created a chunk of size 420, which is longer than the specified 350
# Created a chunk of size 359, which is longer than the specified 350
# Created a chunk of size 759, which is longer than the specified 350
# Created a chunk of size 388, which is longer than the specified 350
# Created a chunk of size 587, which is longer than the specified 350
# Created a chunk of size 401, which is longer than the specified 350
# Created a chunk of size 1346, which is longer than the specified 350
# Created a chunk of size 891, which is longer than the specified 350
# Created a chunk of size 881, which is longer than the specified 350
# Created a chunk of size 625, which is longer than the specified 350
# Created a chunk of size 793, which is longer than the specified 350
# Created a chunk of size 1164, which is longer than the specified 350
# Created a chunk of size 1107, which is longer than the specified 350
# Created a chunk of size 458, which is longer than the specified 350
# Created a chunk of size 494, which is longer than the specified 350
# ...
# Created a chunk of size 459, which is longer than the specified 350
# Created a chunk of size 421, which is longer than the specified 350
# Created a chunk of size 465, which is longer than the specified 350
# Created a chunk of size 391, which is longer than the specified 350
# Created a chunk of size 629, which is longer than the specified 350
# Created a chunk of size 621, which is longer than the specified 350
# Created a chunk of size 440, which is longer than the specified 350
# Created a chunk of size 752, which is longer than the specified 350
# Created a chunk of size 602, which is longer than the specified 350
# Created a chunk of size 382, which is longer than the specified 350
# Created a chunk of size 377, which is longer than the specified 350
# Created a chunk of size 389, which is longer than the specified 350
# Created a chunk of size 352, which is longer than the specified 350
# Created a chunk of size 504, which is longer than the specified 350
# Created a chunk of size 2468, which is longer than the specified 350
# Created a chunk of size 529, which is longer than the specified 350
# Created a chunk of size 420, which is longer than the specified 350
# Created a chunk of size 1635, which is longer than the specified 350
# Created a chunk of size 1128, which is longer than the specified 350
# Created a chunk of size 662, which is longer than the specified 350
# Created a chunk of size 1427, which is longer than the specified 350
# Created a chunk of size 1151, which is longer than the specified 350
# Created a chunk of size 363, which is longer than the specified 350
# Created a chunk of size 1465, which is longer than the specified 350
# Created a chunk of size 734, which is longer than the specified 350
# Created a chunk of size 945, which is longer than the specified 350
# Created a chunk of size 1126, which is longer than the specified 350
# Created a chunk of size 918, which is longer than the specified 350
# Created a chunk of size 599, which is longer than the specified 350
# Created a chunk of size 3090, which is longer than the specified 350
# Created a chunk of size 401, which is longer than the specified 350
# Created a chunk of size 1157, which is longer than the specified 350
# Created a chunk of size 510, which is longer than the specified 350
# Created a chunk of size 778, which is longer than the specified 350
# Created a chunk of size 659, which is longer than the specified 350
# Created a chunk of size 1873, which is longer than the specified 350
# Created a chunk of size 2634, which is longer than the specified 350
# Created a chunk of size 761, which is longer than the specified 350
# Created a chunk of size 897, which is longer than the specified 350
# Created a chunk of size 672, which is longer than the specified 350
# Created a chunk of size 440, which is longer than the specified 350
# Created a chunk of size 367, which is longer than the specified 350
# Created a chunk of size 552, which is longer than the specified 350
# Created a chunk of size 521, which is longer than the specified 350
# Created a chunk of size 2436, which is longer than the specified 350
# Created a chunk of size 918, which is longer than the specified 350
# Created a chunk of size 439, which is longer than the specified 350
# Created a chunk of size 1555, which is longer than the specified 350
# Created a chunk of size 709, which is longer than the specified 350
# Created a chunk of size 1753, which is longer than the specified 350
# Created a chunk of size 1491, which is longer than the specified 350
# Created a chunk of size 1050, which is longer than the specified 350
# Created a chunk of size 353, which is longer than the specified 350
# Created a chunk of size 1074, which is longer than the specified 350
# Created a chunk of size 848, which is longer than the specified 350
# Created a chunk of size 2451, which is longer than the specified 350
# Created a chunk of size 975, which is longer than the specified 350
# Created a chunk of size 650, which is longer than the specified 350
# Created a chunk of size 3158, which is longer than the specified 350
# Created a chunk of size 5253, which is longer than the specified 350
# Created a chunk of size 844, which is longer than the specified 350
# Created a chunk of size 581, which is longer than the specified 350
# Created a chunk of size 1621, which is longer than the specified 350
# Created a chunk of size 1000, which is longer than the specified 350
# Created a chunk of size 1702, which is longer than the specified 350
# Created a chunk of size 466, which is longer than the specified 350
# Created a chunk of size 1059, which is longer than the specified 350
# Created a chunk of size 375, which is longer than the specified 350
# Created a chunk of size 535, which is longer than the specified 350
# Created a chunk of size 355, which is longer than the specified 350
# Created a chunk of size 3524, which is longer than the specified 350
# Created a chunk of size 410, which is longer than the specified 350
# Created a chunk of size 824, which is longer than the specified 350
# Created a chunk of size 794, which is longer than the specified 350
# Created a chunk of size 392, which is longer than the specified 350
# Created a chunk of size 439, which is longer than the specified 350
# Created a chunk of size 799, which is longer than the specified 350
# Created a chunk of size 525, which is longer than the specified 350
# Created a chunk of size 845, which is longer than the specified 350
# Created a chunk of size 542, which is longer than the specified 350
# Created a chunk of size 1051, which is longer than the specified 350
# Created a chunk of size 2059, which is longer than the specified 350
# Created a chunk of size 2188, which is longer than the specified 350
# Created a chunk of size 695, which is longer than the specified 350
# Created a chunk of size 407, which is longer than the specified 350
# Created a chunk of size 596, which is longer than the specified 350
# Created a chunk of size 432, which is longer than the specified 350
# Created a chunk of size 480, which is longer than the specified 350
# Created a chunk of size 727, which is longer than the specified 350
# Created a chunk of size 1853, which is longer than the specified 350
# Created a chunk of size 477, which is longer than the specified 350
# Created a chunk of size 424, which is longer than the specified 350
# Created a chunk of size 609, which is longer than the specified 350
# Created a chunk of size 537, which is longer than the specified 350
# Created a chunk of size 1095, which is longer than the specified 350
# Created a chunk of size 685, which is longer than the specified 350
# Created a chunk of size 977, which is longer than the specified 350
# Created a chunk of size 1280, which is longer than the specified 350
# Created a chunk of size 652, which is longer than the specified 350
# Created a chunk of size 1413, which is longer than the specified 350
# Created a chunk of size 585, which is longer than the specified 350
# Created a chunk of size 357, which is longer than the specified 350
# Created a chunk of size 1176, which is longer than the specified 350
# Created a chunk of size 2625, which is longer than the specified 350
# Created a chunk of size 2616, which is longer than the specified 350
# Created a chunk of size 1297, which is longer than the specified 350
# Created a chunk of size 865, which is longer than the specified 350
# Created a chunk of size 769, which is longer than the specified 350
# Created a chunk of size 520, which is longer than the specified 350
# Created a chunk of size 1546, which is longer than the specified 350
# Created a chunk of size 485, which is longer than the specified 350
# Created a chunk of size 473, which is longer than the specified 350
# Created a chunk of size 1368, which is longer than the specified 350
# Created a chunk of size 1046, which is longer than the specified 350
# Created a chunk of size 1008, which is longer than the specified 350
# Created a chunk of size 891, which is longer than the specified 350
# Created a chunk of size 1317, which is longer than the specified 350
# Created a chunk of size 1501, which is longer than the specified 350
# Created a chunk of size 364, which is longer than the specified 350
# Created a chunk of size 374, which is longer than the specified 350
# Created a chunk of size 1629, which is longer than the specified 350
# Created a chunk of size 462, which is longer than the specified 350
# Created a chunk of size 809, which is longer than the specified 350
# Created a chunk of size 593, which is longer than the specified 350
# Created a chunk of size 615, which is longer than the specified 350
# Created a chunk of size 1012, which is longer than the specified 350
# Created a chunk of size 371, which is longer than the specified 350
# Created a chunk of size 2316, which is longer than the specified 350
# Created a chunk of size 656, which is longer than the specified 350
# Created a chunk of size 2362, which is longer than the specified 350
# Created a chunk of size 3658, which is longer than the specified 350
# Created a chunk of size 1311, which is longer than the specified 350
# Created a chunk of size 583, which is longer than the specified 350
# Created a chunk of size 399, which is longer than the specified 350
# Created a chunk of size 732, which is longer than the specified 350
# Created a chunk of size 1381, which is longer than the specified 350
# Created a chunk of size 2430, which is longer than the specified 350
# Created a chunk of size 765, which is longer than the specified 350
# Created a chunk of size 700, which is longer than the specified 350
# Created a chunk of size 4095, which is longer than the specified 350
# Created a chunk of size 359, which is longer than the specified 350
# Created a chunk of size 556, which is longer than the specified 350
# Created a chunk of size 2185, which is longer than the specified 350
# Created a chunk of size 2720, which is longer than the specified 350
# Created a chunk of size 405, which is longer than the specified 350
# Created a chunk of size 3915, which is longer than the specified 350
# Created a chunk of size 748, which is longer than the specified 350
# Created a chunk of size 483, which is longer than the specified 350
# Created a chunk of size 1098, which is longer than the specified 350
# Created a chunk of size 351, which is longer than the specified 350
# Created a chunk of size 428, which is longer than the specified 350
# Created a chunk of size 1062, which is longer than the specified 350
# Created a chunk of size 1369, which is longer than the specified 350
# Created a chunk of size 1117, which is longer than the specified 350
# Created a chunk of size 441, which is longer than the specified 350
# Created a chunk of size 1976, which is longer than the specified 350
# Created a chunk of size 710, which is longer than the specified 350
# Created a chunk of size 2577, which is longer than the specified 350
# Created a chunk of size 709, which is longer than the specified 350
# Created a chunk of size 638, which is longer than the specified 350
# Created a chunk of size 405, which is longer than the specified 350
# Created a chunk of size 1838, which is longer than the specified 350
# Created a chunk of size 1752, which is longer than the specified 350
# Created a chunk of size 876, which is longer than the specified 350
# Created a chunk of size 624, which is longer than the specified 350
# Created a chunk of size 365, which is longer than the specified 350
# Created a chunk of size 521, which is longer than the specified 350
# Created a chunk of size 896, which is longer than the specified 350
# Created a chunk of size 1243, which is longer than the specified 350
# Created a chunk of size 404, which is longer than the specified 350
# Created a chunk of size 1784, which is longer than the specified 350
# Created a chunk of size 372, which is longer than the specified 350
# Created a chunk of size 370, which is longer than the specified 350
# Created a chunk of size 444, which is longer than the specified 350
# Created a chunk of size 1727, which is longer than the specified 350
# Created a chunk of size 440, which is longer than the specified 350
# Created a chunk of size 379, which is longer than the specified 350
# Created a chunk of size 594, which is longer than the specified 350
# Created a chunk of size 1024, which is longer than the specified 350
# Created a chunk of size 469, which is longer than the specified 350
# Created a chunk of size 558, which is longer than the specified 350
# Created a chunk of size 572, which is longer than the specified 350
# Created a chunk of size 362, which is longer than the specified 350
# Created a chunk of size 1022, which is longer than the specified 350
# Created a chunk of size 799, which is longer than the specified 350
# Created a chunk of size 843, which is longer than the specified 350
# Created a chunk of size 882, which is longer than the specified 350
# Created a chunk of size 723, which is longer than the specified 350
# Created a chunk of size 484, which is longer than the specified 350
# Created a chunk of size 400, which is longer than the specified 350
# Created a chunk of size 7470, which is longer than the specified 350
# Created a chunk of size 398, which is longer than the specified 350
# Caching 12982 chunks to chunks_cache.pkl...
# 12982 chunks loaded.
# Embedding Generation
# No cached embeddings found, generating new ones...
# Using device: mps
# Caching embeddings to embeddings_cache.pkl
# FAISS Index Setup
# FAISS Index contains 12982 vectors.
# Using device: mps
# Top 5 matches [[ 7864 10719  7969  2725  2680]]
#
# Chunk index 7864 with L2 distance 1.1568076610565186:
# As a result, failure of the left engine will result in the most asymmetrical
# thrust (adverse yaw) as the right engine will be providing the remaining thrust. [Figure 13-12]
# 13-23
# Figure 13-12. Forces created during single-engine operation.
# Many twins are designed with a counter-rotating right engine
# ================================================================================
#
# Chunk index 10719 with L2 distance 1.1573790311813354:
# This is
# the most important condition, which causes brake system failures. It is not possible to
# determine exactly when it occurs.
# Information about the brake fluid used by the manufacturer is recorded on a placard
# at the firewall in the engine compartment.
# WHEELS AND BRAKES Chapter 32-40
# 22. 05
# ================================================================================
#
# Chunk index 7969 with L2 distance 1.1752135753631592:
# In maintaining directional control, however, rudder pressure is
# exerted on the side (left or right) of the airplane with the operating engine
# ================================================================================
#
# Chunk index 2725 with L2 distance 1.1839258670806885:
# .15, Green light
# (cid:160)(cid:160)(cid:160)(cid:160)
# LOW PRESSURE - Hydraulic Pump - Standby
# STANDBY HYDRAULIC LOW
# LOW
# PRESSURE PRESSURE
# Condition: The standby hydraulic pump pressure is low.
# Note: With a loss of hydraulic system A and B, the
# rudder is inoperative.
# (cid:160)(cid:160)(cid:160)(cid:160)
# LOW QUANTITY
# STANDBY HYDRAULIC LOW
# LOW
# QUANTITY QUANTITY
# Condition: The standby hydraulic quantity is low.
# 1 Continue normal operation.
# (cid:160)(cid:160)(cid:160)(cid:160)
# Copyright ©The Boeing Company
# ================================================================================
#
# Chunk index 2680 with L2 distance 1.1974406242370605:
# 1O3f- HCyodnrtaeunltiscs
# 737 Flight Crew Operations Manual
# Non-Normal Checklists Chapter NNC
# Hydraulics Section 13
# Table of Contents
# HYDRAULIC PUMP LOW PRESSURE ...................13.1
# HYDRAULIC PUMP OVERHEAT ..........................13.1
# LOSS OF SYSTEM A <>...................................13.2
# LOSS OF SYSTEM B <>...................................13.4
# MANUAL REVERSION or LOSS OF SYSTEM A AND
# SYSTEM B <> ............................................13.8
# STANDBY HYDRAULIC LOW PRESSURE............13.13
# STANDBY HYDRAULIC LOW QUANTITY............13.13
# Copyright ©The Boeing Company
# ================================================================================

# %% [markdown]
# the above set up has the following limitations :
# though there is sufficient response for single basic queries that are obvious, there is only a keyword based response for complex issues like hydraulic failure in the left engine, it addresses hydraulic and left engine separately
#
# this could be beacause of lacking input data
# improving it :
# 1. change in chunking strategy
# 2. post process retrieved chunk material by re-ranking as a secondary filter
# 3. imo a more broad input data should fix it
